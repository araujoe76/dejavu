# %%
#Apagar todos os docs
from pymongo import MongoClient
from pprint import pprint
client = MongoClient()
client = MongoClient('mongodb+srv://TCC:TCCB3@cluster0.tl5lj.mongodb.net/test')
banco = client['TCC_B3']
dados_tcc = banco['TCC_B3']
dados_tcc.drop ()

print ("Documentos apagados")
# Out:
# Documentos apagados

# %%
from pymongo import MongoClient
from pprint import pprint
from datetime import datetime

client = MongoClient()
client = MongoClient('mongodb+srv://TCC:TCCB3@cluster0.tl5lj.mongodb.net/test')
banco = client['TCC_B3']
dados_tcc = banco['TCC_B3']

now = datetime.now()
print ("Inicio")
print (now)

lista = [];
vmes  = 0;

#Carga do arquivo
ref_arquivo = open("\\temp\COTAHIST_A2010.txt","r")
vlinha = 1
for linha in ref_arquivo:
   
   vlinha = vlinha + 1  
   
   if linha[0:2] == '01' and  linha[10:12] == '02':  

       if vmes == 0: 
        mes = linha[6:8]
       
       if vmes != linha[6:8]:
        vmes = linha[6:8]
        vdataini = linha[2:10]
        
       dt = datetime.strptime(linha[2:10], "%Y%m%d")
       dtini = datetime.strptime(vdataini, "%Y%m%d")
       wk = dt.isocalendar()[1]
       wkini = dtini.isocalendar()[1]
       vsemana = wk-wkini+1
     
       vsemanasembug = 1  #true
       if vsemana <= 0 or vsemana >= 6:
            vsemanasembug = 0 #false
            print('Dados')
            print(dtini)
            print(dt)
            print(wk)
            print(wkini)
            print(vmes)
        
       if vsemanasembug == 1:      
          vcod_negociacao = linha[12:24].strip (" ")  
          doc_acao = {
                       "_id" : vcod_negociacao + "_" + linha[2:10],
                       "data_pregao" : linha[2:10],
                       "codigo_negociacao" :  vcod_negociacao,
                       "nome_empresa" : linha[27:39].strip (" "),
                       "preco_abertura" : linha[56:69],
                       "preco_fechamento" : linha[108:121],
                       "semana" : vsemana
                       }
          lista.append(doc_acao)
          #dados_tcc.insert_one(lista)      

dados_tcc.insert_many(lista)        
ref_arquivo.close()

print (str(vlinha) + ' Linhas. Arquivo fechado')

now = datetime.now()
print ("FIM")
print (now)
# Out:
# Inicio
# 2021-05-30 12:20:45.283279
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# 2019-12-30 00:00:00
# 1
# 49
# 12
# Dados
# 2019-12-02 00:00:00
# ...
